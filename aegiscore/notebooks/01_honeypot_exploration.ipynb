# %% [markdown]
# # AegisCore — Honeypot Attack Classifier Exploration
#
# **DEFENSIVE-ONLY**: This notebook analyzes honeypot telemetry for defensive purposes only.

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt

from src.data_generation.honeypot_synth import generate_honeypot_data
from src.training.train_honeypot import train_honeypot

df = generate_honeypot_data(n_samples=5000, seed=42, save=False)
print(df.head())
print(df['label'].value_counts())

# %%
df['label'].value_counts().plot(kind='bar', title='Honeypot Label Distribution')
plt.tight_layout()
plt.show()

# %%
metrics = train_honeypot(df=df, save=False)
print(f"F1 Macro: {metrics['f1_macro']:.4f}")
