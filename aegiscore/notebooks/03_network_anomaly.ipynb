# %% [markdown]
# # AegisCore — Network Anomaly Detection
#
# **DEFENSIVE-ONLY**: Authorized telemetry analysis only.

# %%
import sys; sys.path.insert(0, '..')
from src.data_generation.network_synth import generate_network_data
from src.training.train_network import train_network

df = generate_network_data(n_samples=5000, contamination=0.08, seed=42, save=False)
print(df['label'].value_counts())
metrics = train_network(df=df, save=False)
print(f"F1 Macro: {metrics['f1_macro']:.4f}")
