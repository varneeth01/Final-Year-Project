# %% [markdown]
# # AegisCore — Security Misconfiguration Risk Model
#
# **DEFENSIVE-ONLY**: Authorized configuration data analysis only.

# %%
import sys; sys.path.insert(0, '..')
from src.data_generation.posture_synth import generate_posture_data
from src.training.train_posture import train_posture

df = generate_posture_data(n_samples=5000, seed=42, save=False)
print(df['label'].value_counts())
metrics = train_posture(df=df, save=False)
print(f"F1 Macro: {metrics['f1_macro']:.4f}")
